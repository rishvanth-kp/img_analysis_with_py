# %% [markdown]
# # Chapter 3: Image smoothing
#
# Image smoothing or blurring an image is used to reducice "noise" in an image.

# %% [markdown]
# ## Mean smoothing

# %% [markdown]
# ## Gaussian smoothing
